# %%
import numpy as np
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath('..'))

from utils.config import SimConfig

# %%
RUNNER_SCRIPT = "../runners/run_tcl.sh"
SCRIPT_NAME = "test_added_security_impact.tcl"
CONFIG_FILE = "config.json"

sim_cfg = SimConfig(
    runner=RUNNER_SCRIPT,
    script=SCRIPT_NAME,
    cfg_file=CONFIG_FILE
)

# %%
populate = True

if populate:
    sim_cfg.run(dry_run=False)
