# %%
import numpy as np
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath('..'))

from utils.config import SimConfig

# %%
RUNNER_SCRIPT = "../runners/run_tcl.sh"
SCRIPT_NAME = "sim_added_security_impact.tcl"
CONFIG_FILE = "config_simple.json"

sim_cfg = SimConfig(
    runner=RUNNER_SCRIPT,
    script=SCRIPT_NAME,
    cfg_file=CONFIG_FILE
)

# %%
populate = True

if populate:
    sim_cfg.run(parallel=True, dry_run=False, verbose=True)
# Out:
# Loaded: rng_rounds=3, rng_start=1, entries=12
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 20 1 4 16 LF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 20 1 4 16 MF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 20 1 4 16 HF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 36 1 4 16 LF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 36 1 4 16 MF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 36 1 4 16 HF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 68 1 4 16 LF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 68 1 4 16 MF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 68 1 4 16 HF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 132 1 4 16 LF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 132 1 4 16 MF 1
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 132 1 4 16 HF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_36_1_4_16_LF_1.tcl 36 1 4 16 LF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_20_1_4_16_HF_1.tcl 20 1 4 16 HF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_68_1_4_16_LF_1.tcl 68 1 4 16 LF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_68_1_4_16_MF_1.tcl 68 1 4 16 MF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_36_1_4_16_MF_1.tcl 36 1 4 16 MF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_68_1_4_16_HF_1.tcl 68 1 4 16 HF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_20_1_4_16_MF_1.tcl 20 1 4 16 MF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_36_1_4_16_HF_1.tcl 36 1 4 16 HF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_20_1_4_16_LF_1.tcl 20 1 4 16 LF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_132_1_4_16_MF_1.tcl 132 1 4 16 MF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_132_1_4_16_HF_1.tcl 132 1 4 16 HF 1
# [2026-03-02 16:54:56] Running: ns ./.desert/tmp_sim_added_security_impact_132_1_4_16_LF_1.tcl 132 1 4 16 LF 1
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/132_1_4_16_HF/132_1_4_16_HF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 20 1 4 16 LF 2
# [2026-03-02 16:55:26] Running: ns ./.desert/tmp_sim_added_security_impact_20_1_4_16_LF_2.tcl 20 1 4 16 LF 2
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/132_1_4_16_MF/132_1_4_16_MF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 20 1 4 16 MF 2
# [2026-03-02 16:55:35] Running: ns ./.desert/tmp_sim_added_security_impact_20_1_4_16_MF_2.tcl 20 1 4 16 MF 2
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/132_1_4_16_LF/132_1_4_16_LF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 20 1 4 16 HF 2
# [2026-03-02 16:55:40] Running: ns ./.desert/tmp_sim_added_security_impact_20_1_4_16_HF_2.tcl 20 1 4 16 HF 2
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/68_1_4_16_MF/68_1_4_16_MF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 36 1 4 16 LF 2
# [2026-03-02 16:56:04] Running: ns ./.desert/tmp_sim_added_security_impact_36_1_4_16_LF_2.tcl 36 1 4 16 LF 2
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/68_1_4_16_LF/68_1_4_16_LF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl
log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 36 1 4 16 MF 3
# [2026-03-02 16:58:24] Running: ns ./.desert/tmp_sim_added_security_impact_36_1_4_16_MF_3.tcl 36 1 4 16 MF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_HF/20_1_4_16_HF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 36 1 4 16 HF 3
# [2026-03-02 16:58:25] Running: ns ./.desert/tmp_sim_added_security_impact_36_1_4_16_HF_3.tcl 36 1 4 16 HF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/132_1_4_16_HF/132_1_4_16_HF_2_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 68 1 4 16 LF 3
# [2026-03-02 16:58:27] Running: ns ./.desert/tmp_sim_added_security_impact_68_1_4_16_LF_3.tcl 68 1 4 16 LF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_LF/20_1_4_16_LF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 68 1 4 16 MF 3
# [2026-03-02 16:58:31] Running: ns ./.desert/tmp_sim_added_security_impact_68_1_4_16_MF_3.tcl 68 1 4 16 MF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_MF/20_1_4_16_MF_1_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 68 1 4 16 HF 3
# [2026-03-02 16:58:34] Running: ns ./.desert/tmp_sim_added_security_impact_68_1_4_16_HF_3.tcl 68 1 4 16 HF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_MF/20_1_4_16_MF_2_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 132 1 4 16 LF 3
# [2026-03-02 16:58:52] Running: ns ./.desert/tmp_sim_added_security_impact_132_1_4_16_LF_3.tcl 132 1 4 16 LF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_LF/20_1_4_16_LF_2_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 132 1 4 16 MF 3
# [2026-03-02 16:59:01] Running: ns ./.desert/tmp_sim_added_security_impact_132_1_4_16_MF_3.tcl 132 1 4 16 MF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_HF/20_1_4_16_HF_2_log.out'
# Executing in a thread: source '/home/dmytro/tools/simulators/DESERT_Underwater/DESERT_buildCopy_LOCAL/environment' && /home/dmytro/projects/desert_work/runners/run_tcl.sh /home/dmytro/projects/desert_work/security_impact/sim_added_security_impact.tcl 132 1 4 16 HF 3
# [2026-03-02 16:59:06] Running: ns ./.desert/tmp_sim_added_security_impact_132_1_4_16_HF_3.tcl 132 1 4 16 HF 3
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/132_1_4_16_LF/132_1_4_16_LF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/68_1_4_16_LF/68_1_4_16_LF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/68_1_4_16_MF/68_1_4_16_MF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/68_1_4_16_HF/68_1_4_16_HF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/132_1_4_16_MF/132_1_4_16_MF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/132_1_4_16_HF/132_1_4_16_HF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/36_1_4_16_MF/36_1_4_16_MF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/36_1_4_16_LF/36_1_4_16_LF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/36_1_4_16_HF/36_1_4_16_HF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_LF/20_1_4_16_LF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_MF/20_1_4_16_MF_3_log.out'
# Warning: 'log.out' not found; skipping move to 'data/sim_added_security_impact/20_1_4_16_HF/20_1_4_16_HF_3_log.out'
